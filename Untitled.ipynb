# %%
import numpy as np
import json
from data.src import onehot

# %%
from attention_plot import attention_plot

# %%
x = []
y = []
for programs, labels in programs_and_labels_data:
    train_x = []
    train_y = []
    for i, separate_line in enumerate(programs):
        train_x.append(md.onehot_vec(separate_line, 180))
#       print(len(x))
        train_y.append('{}'.format(labels))
#       print(len(y))
#       print(y)
    x.append(train_x)
    y.append(train_y)

# %%
np.shape(x[0])
# Out:
# (23, 25, 181)

# %%
attention_plot(x[0],np.ones((23,25)))
# Out:
# /home/koyama/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
md = onehot.MakeData()
with open('data/src/dataset.json') as jsonfile:
    vector_dict = json.load(jsonfile)
programs_and_labels_data = md.program_sep(vector_dict)

# %%
with open('./data/src/dataset.json') as jsonfile:
    vector_dict = json.load(jsonfile)

# %%
def onehot_vec(self, vector, dic_size):
    onehot_vector = np.zeros((30,dic_size+1))
    for i,vec in enumerate(vector):
        onehot_vector[i][vec] = 1
    return onehot_vector

# %%
    def program_sep(self, program_data):
        programs = []
        labels = []
        for num in range(1,12):
            for one_program in program_data['{}'.format(num)]:
                one_program_new = []
                one_program_new2 = []
                for token in one_program:
                    if token==17 or token==10 or token==35:
                        one_program_new2.append(token)
                        one_program_new.append(one_program_new2)
                        one_program_new2 = []
                    else:
                        one_program_new2.append(token)
                programs.append(one_program_new)
                labels.append(num)
    
        return zip(programs, labels)

# %%
vocab_size = 180

# %%
#[23,50,181]
from data.src import onehot
    
md = onehot.MakeData()
#dict_size = len(token2vec)
programs_and_labels = md.program_sep(vector_dict)
print(programs_and_labels)
for programs, labels in programs_and_labels:
    x = []
    y = []
    for i,separate_line in enumerate(programs):
        #print(separate_line)
        #print(np.shape(separate_line))
        #print("--")
        x.append(md.onehot_vec(separate_line, 180))
        #print("==")
        y.append(labels)
        #print(np.shape(x))
        #print(np.shape(y))
# Out:
# <zip object at 0x7f30e9ddb588>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-fac052a5b03a> in <module>()
#      13         #print(np.shape(separate_line))
#      14         #print("--")
# ---> 15         x.append(md.onehot_vec(separate_line, 180))
#      16         #print("==")
#      17         y.append(labels)
#
# ~/master_study/copy2-hierarchical-attention-networks/data/src/onehot.py in onehot_vec(self, vector, dic_size)
#       8         onehot_vector = np.zeros((50,dic_size+1))
#       9         for i,vec in enumerate(vector):
# ---> 10             onehot_vector[i][vec] = 1
#      11         return onehot_vector
#      12
#
# IndexError: index 50 is out of bounds for axis 0 with size 50

# %%
md = onehot.MakeData()
print(np.shape(md.onehot_vec(md.program_sep(vector_dict), 180)))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-48a91e8b1577> in <module>()
#       1 md = onehot.MakeData()
# ----> 2 print(np.shape(md.onehot_vec(md.program_sep(vector_dict), 180)))
#
# ~/master_study/copy2-hierarchical-attention-networks/data/src/onehot.py in onehot_vec(self, vector, dic_size)
#       8         onehot_vector = np.zeros((50,dic_size+1))
#       9         for i,vec in enumerate(vector):
# ---> 10             onehot_vector[i][vec] = 1
#      11         return onehot_vector
#      12
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import numpy as np
import json
from tqdm import tqdm
import gc

class MakeData():
    def onehot_vec(self, vector, dic_size):
        onehot_vector = np.zeros((50,dic_size+1))
        for i,vec in enumerate(vector):
            onehot_vector[i][vec] = 1
        return onehot_vector
        
    def program_sep(self, program_data):
        programs = []
        labels = []
        for num in range(1,12):
            for one_program in program_data['{}'.format(num)]:
                one_program_new = []
                one_program_new2 = []
                for token in one_program:
                    if token==17 or token==10 or token==35:
                        one_program_new2.append(token)
                        one_program_new.append(one_program_new2)
                        one_program_new2 = []
                    else:
                        one_program_new2.append(token)
                programs.append(one_program_new)
                for line in programs[-1]:
                    if len(line) > 50:
                        del programs[-1]
                        #print(len(line))
                if len(programs[-1]) > 120:
                    del programs[-1]
                    #print(np.shape(programs[-1]))
                labels.append(num)
    
        return zip(programs, labels)


    def main(self):
        dataset = {}
        with open('./data/src/dataset.json') as jsonfile:
            vector_dict = json.load(jsonfile)
        with open('./data/src/data.json') as f:
            token2vec = json.load(f)
        dict_size = len(token2vec)
        count = 0
        batch_size = 10
        programs_and_labels = self.program_sep(vector_dict)
        for programs, labels in programs_and_labels:
            train_x = []
            train_y = []
            for separate_line in programs:
                train_x.append(self.onehot_vec(separate_line,dict_size))
                train_y.append(labels)
        print(len(train_x))
#    for num in tqdm(range(1,12)):
#        dataset[num] = []
#        for vec in tqdm(vector_dict['{}'.format(num)]):
            #print(num)
            #print(vec)
            #print(len(vec))
#            dataset[num].append(onehot_vec(vec,dict_size))
        #print(dataset)

if __name__=='__main__':
    md = MakeData()
    md.main()
# Out:
# 71

# %%
a =np.ones((23,25))

# %%
len(a[0])
# Out:
# 25
