# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('loss_log.csv', header=-1)

# %%
df_new = df[1]

# %%
plt.figure()
df_new.plot()
#plt.legend(loc='best')
#ax = df.plot(secondary_y=['0', '1'])
#ax.set_ylabel('CD の売上', fontdict = {"fontproperties": fontprop})
#ax.right_ax.set_ylabel('AB スケール', fontdict = {"fontproperties": fontprop})
plt.show()
